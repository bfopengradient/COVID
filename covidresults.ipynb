# %% [markdown]
# ## COVID19 Vector Autoregression Analysis.

# %%
#Covid class is attached in another repo: c19.py
from Downloads.c19 import cov19

# %%
#CDC data is provided in this repo. See repo containing cdc.csv.
#Data covers period 31/12/2019 to 13/4/2020 and has daily observations. 
#The data is in raw from but for the VAR analysis and the charts below data was logged and differenced.   
#First three records from cdc datset.
cov19.data.head(3)
# Out:
#                location  new_cases  new_deaths  total_cases  total_deaths
# date
# 2019-12-31  Afghanistan          0           0            0             0
# 2020-01-01  Afghanistan          0           0            0             0
# 2020-01-02  Afghanistan          0           0            0             0

# %% [markdown]
# ### Australia

# %%
#To run the models for any country, feed in the data(cov19.data) and the country of interest.
# X axis labels: L1.new_cases is the one day lag of new cases.. same applies for deaths. 
#Likewise L14 is two week old data.

cov19.country(cov19.data,'Australia')
# Out:
# VAR Analysis of COVID-19 in Australia

# %% [markdown]
# ### Ireland

# %%
cov19.country(cov19.data,'Ireland')
# Out:
# VAR Analysis of COVID-19 in Ireland

# %% [markdown]
# ### South Korea

# %%
cov19.country(cov19.data,'South Korea' )
# Out:
# VAR Analysis of COVID-19 in South Korea
